# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
YOLO_CONFIG_DIR = '/content/gdrive/MyDrive/YOLOMODEL'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# Import dependencies
import os
from ultralytics import YOLO

# %%
#load a model
model = YOLO("yolov8n.yaml") #build a new model from scratch

# %%
#use the model
results = model.train(data=os.path.join(YOLO_CONFIG_DIR,"config.yaml"), epochs=20)  # train the model
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/YOLOMODEL/TrainedYoloCustomDataset'
